# %%
import matplotlib.pyplot as plt

# parameters for plot of uniform prior for model selection
l1 = 100
l2 = 350
l0 = 275 # optimum value

fig = plt.figure()
ax = fig.subplots()
 
ax.plot([1, 2, 3, 4], [0, 0.5, 1, 0.2])
